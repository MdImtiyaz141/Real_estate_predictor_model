# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/corrected_data.csv')

# %%
data.head()
# Out:
#                      property_name  \
# 0  Sumadhuras Gardens By The Brook
# 1  Sumadhuras Gardens By The Brook
# 2                      The Olympus
# 3      Technopolis Solitaire Unity
# 4      Technopolis Solitaire Unity
#
#                                             seller  facilities  advantages  \
# 0              Sumadhura Infracon Pvt. Ltd.Builder          19    6.565000
# 1              Sumadhura Infracon Pvt. Ltd.Builder          19    6.565000
# 2              Sumadhura Infracon Pvt. Ltd.Builder          27    7.209091
# 3  TECHNOPOLIS CONSTRUCTION COMPANY PVT LTDBuilder          21    6.225000
# 4  TECHNOPOLIS CONSTRUCTION COMPANY PVT LTDBuilder          21    6.225000
#
#    column0    column1              column2  column3                  column4  \
# 0        2  Apartment  Super Built-up Area   1362.5  (119.38 - 133.78 sq.m.)
# 1        3  Apartment  Super Built-up Area   1652.5  (150.97 - 156.08 sq.m.)
# ...

# %%
data.rename(columns={'column0':'BHK','column1':'property_type','column2':'Area_type',
                     'column3':'avg_sba','column4':'area_sqft','column5':'Avg_prics',
                     'total project area':'tpa'},inplace=True)

# %%
data.isnull().sum()
# Out:
# property_name      0
# seller             0
# facilities         0
# advantages        44
# BHK                0
# property_type      0
# Area_type          0
# avg_sba            0
# area_sqft          0
# Avg_prics         19
# floors            12
# units             16
# tpa               22
# towers            23
# open area        277
# address            0
# dtype: int64

# %% [markdown]
# - AR Homes Rise:
#
#
#
# This locality ranks #6 in Top 100 in West Hyderabad. Some of the popular features of Kollur are:
#
# Along ORR
#
# Close to Commercial Zones
#
# Sound Rail Connectivity
#
# Upcoming IT Hub
#
# The existing residents of Kollur gave it an average rating of 4.1, out of 5. Most of the reviews mention that this locality has:
#
# Good Public Transport
#
# Well-maintained Roads
#
# Good Schools are nearby
#
# Easy Cab/Auto Availability
#
# Good Hospitals are nearby
#
# Safe at Night

# %% [markdown]
# - Madhu Park Ville
# This locality ranks #4 in Top 100 in West Hyderabad. Some of the popular features of Tellapur are:
#
# Popular Industrial Hub
#
# Affordable Locality
#
# Near Upcoming Mall
#
# Good Road Connectivity
#
# The existing residents of Tellapur gave it an average rating of 4.1, out of 5. Most of the reviews mention that this locality has:
#
# Good Public Transport
#
# Good Schools are nearby
#
# Well-maintained Roads
#
# Easy Cab/Auto Availability
#
# Good Hospitals are nearby
#
# Safe at Night

# %%
df = data[data['advantages'].isnull()]

# %%
df
# Out:
#                        property_name  \
# 33                     AR Homes Rise
# 34                     AR Homes Rise
# 35                     AR Homes Rise
# 40                  Madhu Park Ville
# 41                  Madhu Park Ville
# 64                        SN Enclave
# 65                        SN Enclave
# 97              Devi Homes Samruddhi
# 98              Devi Homes Samruddhi
# 101      The Prestige City Hyderabad
# 102      The Prestige City Hyderabad
# 103      The Prestige City Hyderabad
# 118            Lalitha Divine County
# 119            Lalitha Divine County
# 120           Subishi Fortuna Towers
# 121           Subishi Fortuna Towers
# 141                  Nirvana Elite 5
# 142                  Nirvana Belleza
# 173                EIPL The Tamarind
# 186          Riddhi Pramukh Elegance
# 187          Riddhi Pramukh Elegance
# 188          Riddhi Pramukh Elegance
# 226               Sri Krishna County
# 250                Bricks Cyberwoods
# ...

# %%
df.loc[df[df['property_name'] == 'Infocity Majestic'].index,'advantages'] = 11.244

# %%
df.loc[df[df['property_name'] == 'Rubrick Tripura'].index,'advantages'] = 7.65

# %%
df.loc[df[df['property_name'] == 'Lalitha Majestic'].index,'advantages']=7.11

# %%
df.loc[df[df['property_name'] == 'Sri Krishna County'].index,'advantages']=6.9

# %%
df.loc[df[df['property_name'] == 'Riddhi Pramukh Elegance'].index,'advantages']=6.47

# %%
df.loc[df[df['property_name'] == 'EIPL The Tamarind'].index,'advantages']=8.42

# %%
df.loc[df[df['property_name'] == 'Nirvana Belleza'].index,'advantages']=6.5

# %%
df[df['property_name'] == 'Nirvana Belleza']['advantages']
# Out:
# 142    6.5
# Name: advantages, dtype: float64

# %%
df.isnull().sum()
# Out:
# property_name     0
# seller            0
# facilities        0
# advantages       32
# BHK               0
# property_type     0
# Area_type         0
# avg_sba           0
# area_sqft         0
# Avg_prics         3
# floors            3
# units             5
# tpa               2
# towers            6
# open area        38
# address           0
# dtype: int64

# %% [markdown]
# - Infocity Majestic - 11.244
# - Rubrick Tripura - 7.65
# - Lalitha Majestic - 7.11
# - Bricks Cyberwoods - 6.7
# - Sri Krishna County - 6.9
# - Riddhi Pramukh Elegance - 6.47
# - EIPL The Tamarind - 8.42
# - Nirvana Belleza - 6.5

# %%
import seaborn as sns
sns.boxplot(data['advantages'])
# Out:
# <Axes: ylabel='advantages'>

# %%
data[data['advantages']>17.5]
# True Feature desciption as per the site
# Out:
#                     property_name               seller  facilities  \
# 310  Aditi Sri Shiva Balaji Elite  ADITI AVENUESDealer          11
#
#      advantages  BHK property_type    Area_type  avg_sba       area_sqft  \
# 310   18.885714    2     Apartment  Carpet Area   1215.0  (112.88 sq.m.)
#
#      Avg_prics  floors  units  tpa  towers open area            address
# 310        NaN     5.0   20.0  NaN     1.0       NaN  isnapur,hyderabad

# %%
data.update(df)

# %%
data['advantages'].mean()
# Out:
# 8.43294436119436

# %%
data['advantages'].fillna(8.41,inplace=True)

# %%
data.isnull().sum()
# Out:
# property_name      0
# seller             0
# facilities         0
# advantages         0
# BHK                0
# property_type      0
# Area_type          0
# avg_sba            0
# area_sqft          0
# Avg_prics         19
# floors            12
# units             16
# tpa               22
# towers            23
# open area        277
# address            0
# dtype: int64

# %%
df1 = data[data['Avg_prics'].isnull()].copy()

# %%
df1
# Out:
#                     property_name  \
# 20           Aliens Space Station
# 22           Aliens Space Station
# 52                  Ramky Nextown
# 97           Devi Homes Samruddhi
# 139      Venkatadri Vajra S Abode
# 140      Venkatadri Vajra S Abode
# 162       P Chenna Ramulus Mahaan
# 186       Riddhi Pramukh Elegance
# 205              Aakruthi Arcadia
# 206              Aakruthi Arcadia
# 229                Aparna Synergy
# 233               Om Sree Gallaxy
# 237                   Arkala Life
# 244               Aparna Serenity
# 305    Praneeth Pranav Townsquare
# 310  Aditi Sri Shiva Balaji Elite
# 316          Himalaya Seven Hills
# 331                    Team4 Nyla
# 359           Tripura Green Alpha
#
#                                                 seller  facilities  \
# 20                    Aliens Developers Pvt LtdBuilder        25.0
# 22                    Aliens Developers Pvt LtdBuilder        25.0
# ...

# %% [markdown]
# - Aliens Space Station - [1.2,3]
# - Ramky Nextown - 0.55
# - Devi Homes Samruddhi - 0.68
# - Venkatadri Vajra S Abode - [0.78,0.91]
# - P Chenna Ramulus Mahaan - 0.48
# - Riddhi Pramukh Elegance - 1.48
# - Aakruthi Arcadia - [0.64,0.78]
# - Aparna Synergy - [0.77,1.15]
# - Om Sree Gallaxy - 0.92
# - Arkala Life - [0.55,0.81]
# - Aparna Serenity - 1
# - Praneeth Pranav Townsquare - 0.82
# - Aditi Sri Shiva Balaji Elite - 0.48
# - Himalaya Seven Hills - average
# - Team4 Nyla - average
# - Tripura Green Alpha - 0.9

# %%
df1[df1['property_name'] == 'Aliens Space Station'].index
# Out:
# Int64Index([20, 22], dtype='int64')

# %%
df1.loc[df1[df1['property_name'] == 'Aliens Space Station'].index,'Avg_prics'] = np.array([1.2,3])

# %%
df1.loc[df1[df1['property_name'] == 'Ramky Nextown'].index,'Avg_prics'] = 0.55

# %%
df1.loc[df1[df1['property_name'] == 'Venkatadri Vajra S Abode'].index,'Avg_prics'] = np.array([0.78,0.91])

# %%
df1.loc[df1[df1['property_name'] == 'P Chenna Ramulus Mahaan'].index,'Avg_prics'] = 0.48

# %%
df1.loc[df1[df1['property_name'] == 'Riddhi Pramukh Elegance'].index,'Avg_prics'] = 1.48

# %%
df1.loc[df1[df1['property_name'] == 'Aakruthi Arcadia'].index,'Avg_prics'] = np.array([0.64,0.78])

# %%
df1.loc[df1[df1['property_name'] == 'Aparna Synergy'].index,'Avg_prics'] = 0.77

# %%
df1.loc[df1[df1['property_name'] == 'Om Sree Gallaxy'].index,'Avg_prics'] = 0.92

# %%
df1.loc[df1[df1['property_name'] == 'Arkala Life'].index,'Avg_prics'] = 0.55

# %%
df1.loc[df1[df1['property_name'] == 'Aparna Serenity'].index,'Avg_prics'] = 1

# %%
df1.loc[df1[df1['property_name'] == 'Praneeth Pranav Townsquare'].index,'Avg_prics'] = 0.82

# %%
df1.loc[df1[df1['property_name'] == 'Aditi Sri Shiva Balaji Elite'].index,'Avg_prics'] = 0.48

# %%
df1.loc[df1[df1['property_name'] == 'Tripura Green Alpha'].index,'Avg_prics'] = 0.9

# %%
data.update(df1)

# %%
data.isnull().sum()
# Out:
# property_name      0
# seller             0
# facilities         0
# advantages         0
# BHK                0
# property_type      0
# Area_type          0
# avg_sba            0
# area_sqft          0
# Avg_prics          3
# floors            12
# units             16
# tpa               22
# towers            23
# open area        277
# address            0
# dtype: int64

# %%
sns.boxplot(data['Avg_prics'])
# Out:
# <Axes: ylabel='Avg_prics'>

# %%
# outliers detection and cleaning
#
Q_3 = data['Avg_prics'].quantile(0.75)
Q_1 = data['Avg_prics'].quantile(0.25)
upper_whisker = Q_3 + (1.5+(Q_3-Q_1))
print(upper_whisker)
# Out:
# 3.8165875000000002

# %%
temp_df = data[data['Avg_prics']>upper_whisker].copy()

# %%
temp_df.shape
# Out:
# (17, 16)

# %%
temp_df
# Out:
#                          property_name  \
# 7                      Iris by Raghava
# 23                Aliens Space Station
# 39            The Pearl By Auro Realty
# 43                      Lumbini Elysee
# 123               BSCPL Bollineni Bion
# 127            Mahaveer Crystal Garden
# 132                Prestige Clairemont
# 141                    Nirvana Elite 5
# 189            Sri Aditya Le Grandiose
# 190  Prestige Vaishnaoi Rainbow Waters
# 191  Prestige Vaishnaoi Rainbow Waters
# 203                   Shangrila Abbham
# 223                   NSL East Luxoria
# 284                  Sattva Lake Ridge
# 285                  Sattva Lake Ridge
# 337                  Navayuga Godavari
# 356                   Sobha Waterfront
#
#                                                 seller  facilities  \
# 7                                      MagicPropDealer        11.0
# 23                    Aliens Developers Pvt LtdBuilder        25.0
# ...

# %% [markdown]
# - All the outliers present in the data are real data points, their value is correct as per the website.

# %%
data['Avg_prics'].mean()
# Out:
# 1.4211858938547486

# %%
data['Avg_prics'].fillna(1.42,inplace=True)

# %%
data.isnull().sum()
# Out:
# property_name      0
# seller             0
# facilities         0
# advantages         0
# BHK                0
# property_type      0
# Area_type          0
# avg_sba            0
# area_sqft          0
# Avg_prics          0
# floors            12
# units             16
# tpa               22
# towers            23
# open area        277
# address            0
# dtype: int64

# %%
new_df = data[data['floors'].isnull()].copy()

# %%
new_df
# Out:
#                    property_name  \
# 2                    The Olympus
# 95           The Edge by Risinia
# 96           The Edge by Risinia
# 141              Nirvana Elite 5
# 142              Nirvana Belleza
# 194         Vajra The Royal Park
# 195         Vajra The Royal Park
# 247          Cybercity Westbrook
# 248          Cybercity Westbrook
# 249          Cybercity Westbrook
# 258  Suvela Projects Khairatabad
# 293               Modi Lake View
#
#                                                seller  facilities  advantages  \
# 2                 Sumadhura Infracon Pvt. Ltd.Builder        27.0    7.209091
# 95                            Risinia BuildersBuilder        18.0   10.966667
# 96                            Risinia BuildersBuilder        18.0   10.966667
# 141                 Nirvana Infrabuild Pvt LtdBuilder        33.0    8.410000
# 142                 Nirvana Infrabuild Pvt LtdBuilder        26.0    6.500000
# ...

# %% [markdown]
# - The Olympus - 44
# - The Edge by Risinia - 09
# - Nirvana Elite 5 - 05
# - Nirvana Belleza - 04
# - Vajra The Royal Park - 09
# - Cybercity Westbrook - 35
# - Suvela Projects Khairatabad - 05
# - Modi Lake View - 07

# %%
new_df.loc[new_df[new_df['property_name'] == 'The Olympus'].index,'floors']= 44

# %%
new_df.loc[new_df[new_df['property_name'] == 'The Edge by Risinia'].index,'floors'] = 9

# %%
new_df.loc[new_df[new_df['property_name'] == 'Nirvana Elite 5'].index,'floors'] = 5

# %%
new_df.loc[new_df[new_df['property_name'] == 'Nirvana Belleza'].index,'floors'] = 4

# %%
new_df.loc[new_df[new_df['property_name'] == 'Vajra The Royal Park'].index,'floors'] = 9

# %%
new_df.loc[new_df[new_df['property_name'] == 'Cybercity Westbrook'].index,'floors'] = 35

# %%
new_df.loc[new_df[new_df['property_name'] == 'Suvela Projects Khairatabad'].index,'floors'] = 5

# %%
new_df.loc[new_df[new_df['property_name'] == 'Modi Lake View'].index,'floors'] = 7

# %%
new_df[new_df['property_name'] == 'Modi Lake View']['floors']
# Out:
# 293    7.0
# Name: floors, dtype: float64

# %%
data.update(new_df)

# %%
sns.boxplot(data['floors'])
# Out:
# <Axes: ylabel='floors'>

# %%
data.isnull().sum()
# Out:
# property_name      0
# seller             0
# facilities         0
# advantages         0
# BHK                0
# property_type      0
# Area_type          0
# avg_sba            0
# area_sqft          0
# Avg_prics          0
# floors             0
# units             16
# tpa               22
# towers            23
# open area        277
# address            0
# dtype: int64

# %%
units_df = data[data['units'].isnull()].copy()

# %%
units_df
# Out:
#                    property_name  \
# 19     The Regent by Auro Realty
# 104             Hallmark Skyrena
# 105             Hallmark Skyrena
# 235         Sri Saikrishna Prime
# 238                 Divine Space
# 239                 Divine Space
# 258  Suvela Projects Khairatabad
# 276                Haimi Nirvana
# 277                Haimi Nirvana
# 283            Sattva Lake Ridge
# 284            Sattva Lake Ridge
# 285            Sattva Lake Ridge
# 337            Navayuga Godavari
# 348            Infocity Majestic
# 349            Infocity Majestic
# 350            Infocity Majestic
#
#                                                 seller  facilities  \
# 19                  AURO REALTY PRIVATE LIMITEDBuilder        20.0
# 104                           Hallmark BuildersBuilder        27.0
# 105                           Hallmark BuildersBuilder        27.0
# 235               SRI SAI KRISHNA CONSTRUCTIONSBuilder         8.0
# ...

# %% [markdown]
# - The Regent by Auro Realty - 1400
# - Hallmark Skyrena - 678
# - Sri Saikrishna Prime - 25
# - Divine Space - 876
# - Suvela Projects Khairatabad - 10
# - Haimi Nirvana - 65
# - Sattva Lake Ridge - 897
# - Navayuga Godavari - 130
# - Infocity Majestic - 99

# %%
units_df.loc[units_df[units_df['property_name'] == 'The Regent by Auro Realty'].index, 'units'] = 1400
units_df.loc[units_df[units_df['property_name'] == 'Hallmark Skyrena'].index, 'units'] = 678
units_df.loc[units_df[units_df['property_name'] == 'Sri Saikrishna Prime'].index, 'units'] = 25
units_df.loc[units_df[units_df['property_name'] == 'Divine Space'].index, 'units'] = 876
units_df.loc[units_df[units_df['property_name'] == 'Suvela Projects Khairatabad'].index, 'units'] = 10
units_df.loc[units_df[units_df['property_name'] == 'Haimi Nirvana'].index, 'units'] = 65
units_df.loc[units_df[units_df['property_name'] == 'Sattva Lake Ridge'].index, 'units'] = 897
units_df.loc[units_df[units_df['property_name'] == 'Navayuga Godavari'].index, 'units'] = 130
units_df.loc[units_df[units_df['property_name'] == 'Infocity Majestic'].index, 'units'] = 99

# %%
units_df
# Out:
#                    property_name  \
# 19     The Regent by Auro Realty
# 104             Hallmark Skyrena
# 105             Hallmark Skyrena
# 235         Sri Saikrishna Prime
# 238                 Divine Space
# 239                 Divine Space
# 258  Suvela Projects Khairatabad
# 276                Haimi Nirvana
# 277                Haimi Nirvana
# 283            Sattva Lake Ridge
# 284            Sattva Lake Ridge
# 285            Sattva Lake Ridge
# 337            Navayuga Godavari
# 348            Infocity Majestic
# 349            Infocity Majestic
# 350            Infocity Majestic
#
#                                                 seller  facilities  \
# 19                  AURO REALTY PRIVATE LIMITEDBuilder        20.0
# 104                           Hallmark BuildersBuilder        27.0
# 105                           Hallmark BuildersBuilder        27.0
# 235               SRI SAI KRISHNA CONSTRUCTIONSBuilder         8.0
# ...

# %%
data.update(units_df)

# %%
sns.boxplot(data['units'])
# Out:
# <Axes: ylabel='units'>

# %%
# outliers detection and cleaning
#
Q_3 = data['units'].quantile(0.75)
Q_1 = data['units'].quantile(0.25)
upper_whisker = Q_3 + (1.5+(Q_3-Q_1))
print(upper_whisker)
# Out:
# 1603.5

# %%
data[data['units'] > 1603.5]
# Out:
#                    property_name  \
# 13               Aparna Newlands
# 14               Aparna Newlands
# 20          Aliens Space Station
# 21          Aliens Space Station
# 22          Aliens Space Station
# 23          Aliens Space Station
# 24             Candeur Lakescape
# 25             Candeur Lakescape
# 26             Candeur Lakescape
# 87               Incor Lake City
# 88               Incor Lake City
# 89               Incor Lake City
# 101  The Prestige City Hyderabad
# 102  The Prestige City Hyderabad
# 103  The Prestige City Hyderabad
# 128         Vasavi Anandanilayam
# 129         Vasavi Anandanilayam
# 130         Vasavi Anandanilayam
# 167           Pacifica Hillcrest
# 168           Pacifica Hillcrest
# 169           Pacifica Hillcrest
# 178               Vasavi Sarovar
# 179               Vasavi Sarovar
# 180               Vasavi Sarovar
# 182               Honer Signatis
# 183               Honer Signatis
# 229               Aparna Synergy
# ...

# %% [markdown]
# - They are not outliers they do have extreme values for the big projects

# %%
data.isnull().sum()
# Out:
# property_name      0
# seller             0
# facilities         0
# advantages         0
# BHK                0
# property_type      0
# Area_type          0
# avg_sba            0
# area_sqft          0
# Avg_prics          0
# floors             0
# units              0
# tpa               22
# towers            23
# open area        277
# address            0
# dtype: int64

# %%
tpa_df = data[data['tpa'].isnull()].copy()

# %%
tpa_df
# Out:
#                     property_name  \
# 20           Aliens Space Station
# 21           Aliens Space Station
# 22           Aliens Space Station
# 23           Aliens Space Station
# 95            The Edge by Risinia
# 96            The Edge by Risinia
# 104              Hallmark Skyrena
# 105              Hallmark Skyrena
# 108            Aparna Cyber Shine
# 109            Aparna Cyber Shine
# 194          Vajra The Royal Park
# 195          Vajra The Royal Park
# 238                  Divine Space
# 239                  Divine Space
# 247           Cybercity Westbrook
# 248           Cybercity Westbrook
# 249           Cybercity Westbrook
# 253               MPM SS Pinnacle
# 254               MPM SS Pinnacle
# 310  Aditi Sri Shiva Balaji Elite
# 315          Himalaya Seven Hills
# 316          Himalaya Seven Hills
#
#                                                seller  facilities  advantages  \
# 20                   Aliens Developers Pvt LtdBuilder        25.0   10.030769
# ...

# %% [markdown]
# - Aliens Space Station - 20 Acres
# - The Edge by Risinia - 2 Acres
# - Hallmark Skyrena - 6.15 Acres
# - Aparna Cyber Shine - 3.04 Acres
# - Vajra The Royal Park - 6 Acre
# - Divine Space - 8 Acres
# - Cybercity Westbrook - 7.8 Acres
# - MPM SS Pinnacle - 2.65 Acres
# - Aditi Sri Shiva Balaji Elite - 0.15 Acres
# - Himalaya Seven Hills - 1.5 Acres

# %%
tpa_df.loc[tpa_df[tpa_df['property_name'] == 'Aliens Space Station'].index,'tpa'] = 20
tpa_df.loc[tpa_df[tpa_df['property_name'] == 'The Edge by Risinia'].index,'tpa'] = 2
tpa_df.loc[tpa_df[tpa_df['property_name'] == 'Hallmark Skyrena'].index,'tpa'] = 6.15
tpa_df.loc[tpa_df[tpa_df['property_name'] == 'Aparna Cyber Shine'].index,'tpa'] = 3.04
tpa_df.loc[tpa_df[tpa_df['property_name'] == 'Vajra The Royal Park'].index,'tpa'] = 6
tpa_df.loc[tpa_df[tpa_df['property_name'] == 'Divine Space'].index,'tpa'] = 8
tpa_df.loc[tpa_df[tpa_df['property_name'] == 'Cybercity Westbrook'].index,'tpa'] = 7.8
tpa_df.loc[tpa_df[tpa_df['property_name'] == 'MPM SS Pinnacle'].index,'tpa'] = 2.65
tpa_df.loc[tpa_df[tpa_df['property_name'] == 'Aditi Sri Shiva Balaji Elite'].index,'tpa'] = 0.15
tpa_df.loc[tpa_df[tpa_df['property_name'] == 'Himalaya Seven Hills'].index,'tpa'] = 1.5

# %%
tpa_df
# Out:
#                     property_name  \
# 20           Aliens Space Station
# 21           Aliens Space Station
# 22           Aliens Space Station
# 23           Aliens Space Station
# 95            The Edge by Risinia
# 96            The Edge by Risinia
# 104              Hallmark Skyrena
# 105              Hallmark Skyrena
# 108            Aparna Cyber Shine
# 109            Aparna Cyber Shine
# 194          Vajra The Royal Park
# 195          Vajra The Royal Park
# 238                  Divine Space
# 239                  Divine Space
# 247           Cybercity Westbrook
# 248           Cybercity Westbrook
# 249           Cybercity Westbrook
# 253               MPM SS Pinnacle
# 254               MPM SS Pinnacle
# 310  Aditi Sri Shiva Balaji Elite
# 315          Himalaya Seven Hills
# 316          Himalaya Seven Hills
#
#                                                seller  facilities  advantages  \
# 20                   Aliens Developers Pvt LtdBuilder        25.0   10.030769
# ...

# %%
data.update(tpa_df)

# %%
data.isnull().sum()
# Out:
# property_name      0
# seller             0
# facilities         0
# advantages         0
# BHK                0
# property_type      0
# Area_type          0
# avg_sba            0
# area_sqft          0
# Avg_prics          0
# floors             0
# units              0
# tpa                0
# towers            23
# open area        277
# address            0
# dtype: int64

# %%
sns.boxplot(data['tpa'])
# Out:
# <Axes: ylabel='tpa'>

# %%
# outliers detection and cleaning
#
Q_3 = data['tpa'].quantile(0.75)
Q_1 = data['tpa'].quantile(0.25)
upper_whisker = Q_3 + (1.5+(Q_3-Q_1))
print(upper_whisker)
# Out:
# 14.9

# %%
data[data['tpa']>upper_whisker]
# Out:
#                    property_name  \
# 20          Aliens Space Station
# 21          Aliens Space Station
# 22          Aliens Space Station
# 23          Aliens Space Station
# 87               Incor Lake City
# 88               Incor Lake City
# 89               Incor Lake City
# 101  The Prestige City Hyderabad
# 102  The Prestige City Hyderabad
# 103  The Prestige City Hyderabad
# 128         Vasavi Anandanilayam
# 129         Vasavi Anandanilayam
# 130         Vasavi Anandanilayam
# 154          Silpas Kalpavriksha
# 155          Silpas Kalpavriksha
# 178               Vasavi Sarovar
# 179               Vasavi Sarovar
# 180               Vasavi Sarovar
# 182               Honer Signatis
# 183               Honer Signatis
# 229               Aparna Synergy
# 230               Aparna Synergy
# 233              Om Sree Gallaxy
# 234              Om Sree Gallaxy
# 241         Aparna Sarovar Zicon
# 242         Aparna Sarovar Zicon
# 243         Aparna Sarovar Zicon
# ...

# %% [markdown]
# - Need to be present in the data as they are the real points from the website

# %%
tower_df = data[data['towers'].isnull()].copy()

# %%
tower_df
# Out:
#                     property_name  \
# 8    Unnati Shree Rath Apartments
# 9    Unnati Shree Rath Apartments
# 50     Syamantaka Emerald Heights
# 51     Syamantaka Emerald Heights
# 95            The Edge by Risinia
# 96            The Edge by Risinia
# 141               Nirvana Elite 5
# 142               Nirvana Belleza
# 170                Gokul Bhuvanam
# 171                Gokul Bhuvanam
# 238                  Divine Space
# 239                  Divine Space
# 247           Cybercity Westbrook
# 248           Cybercity Westbrook
# 249           Cybercity Westbrook
# 258   Suvela Projects Khairatabad
# 293                Modi Lake View
# 324          Teja Fortune Heights
# 325          Teja Fortune Heights
# 337             Navayuga Godavari
# 351              Sunshine Destino
# 352              Sunshine Destino
# 353              Sunshine Destino
#
#                                                 seller  facilities  \
# ...

# %% [markdown]
# - Unnati Shree Rath Apartments - 2
# - Syamantaka Emerald Heights - 2
# - The Edge by Risinia -2
# - Nirvana Elite 5 - 1
# - Nirvana Belleza - 1
# - Gokul Bhuvanam - 1
# - Divine Space - 9
# - Cybercity Westbrook - 3
# - Suvela Projects Khairatabad -1
# - Modi Lake View - 3
# - Teja Fortune Heights -4
# - Navayuga Godavari -1
# - Sunshine Destino -4

# %%
tower_df.loc[tower_df[tower_df['property_name'] == 'Unnati Shree Rath Apartments'].index,'towers'] = 2
tower_df.loc[tower_df[tower_df['property_name'] == 'Syamantaka Emerald Heights'].index,'towers'] = 2
tower_df.loc[tower_df[tower_df['property_name'] == 'The Edge by Risinia'].index,'towers'] = 2
tower_df.loc[tower_df[tower_df['property_name'] == 'Nirvana Elite 5'].index,'towers'] = 1
tower_df.loc[tower_df[tower_df['property_name'] == 'Nirvana Belleza'].index,'towers'] = 1
tower_df.loc[tower_df[tower_df['property_name'] == 'Gokul Bhuvanam'].index,'towers'] = 1
tower_df.loc[tower_df[tower_df['property_name'] == 'Divine Space'].index,'towers'] = 9
tower_df.loc[tower_df[tower_df['property_name'] == 'Cybercity Westbrook'].index,'towers'] = 3
tower_df.loc[tower_df[tower_df['property_name'] == 'Suvela Projects Khairatabad'].index,'towers'] = 1
tower_df.loc[tower_df[tower_df['property_name'] == 'Modi Lake View'].index,'towers'] = 3
tower_df.loc[tower_df[tower_df['property_name'] == 'Teja Fortune Heights'].index,'towers'] = 4
tower_df.loc[tower_df[tower_df['property_name'] == 'Navayuga Godavari'].index,'towers'] = 1
tower_df.loc[tower_df[tower_df['property_name'] == 'Sunshine Destino'].index,'towers'] = 4

# %%
tower_df
# Out:
#                     property_name  \
# 8    Unnati Shree Rath Apartments
# 9    Unnati Shree Rath Apartments
# 50     Syamantaka Emerald Heights
# 51     Syamantaka Emerald Heights
# 95            The Edge by Risinia
# 96            The Edge by Risinia
# 141               Nirvana Elite 5
# 142               Nirvana Belleza
# 170                Gokul Bhuvanam
# 171                Gokul Bhuvanam
# 238                  Divine Space
# 239                  Divine Space
# 247           Cybercity Westbrook
# 248           Cybercity Westbrook
# 249           Cybercity Westbrook
# 258   Suvela Projects Khairatabad
# 293                Modi Lake View
# 324          Teja Fortune Heights
# 325          Teja Fortune Heights
# 337             Navayuga Godavari
# 351              Sunshine Destino
# 352              Sunshine Destino
# 353              Sunshine Destino
#
#                                                 seller  facilities  \
# ...

# %%
data.update(tower_df)

# %%
sns.boxplot(data['towers'])
# Out:
# <Axes: ylabel='towers'>

# %%
data[data['towers']>80]
# Out:
#            property_name                            seller  facilities  \
# 20  Aliens Space Station  Aliens Developers Pvt LtdBuilder        25.0
# 21  Aliens Space Station  Aliens Developers Pvt LtdBuilder        25.0
# 22  Aliens Space Station  Aliens Developers Pvt LtdBuilder        25.0
# 23  Aliens Space Station  Aliens Developers Pvt LtdBuilder        25.0
#
#     advantages  BHK property_type            Area_type  avg_sba  \
# 20   10.030769  2.0     Apartment  Super Built-up Area   1254.0
# 21   10.030769  3.0     Apartment  Super Built-up Area   1820.0
# 22   10.030769  4.0     Apartment  Super Built-up Area   3569.0
# 23   10.030769  5.0     Apartment  Super Built-up Area   6309.5
#
#                   area_sqft  Avg_prics  floors   units   tpa  towers  \
# 20            (116.5 sq.m.)      1.200    30.0  2200.0  20.0    83.0
# 21  (133.04 - 205.13 sq.m.)      1.555    30.0  2200.0  20.0    83.0
# 22           (331.57 sq.m.)      3.000    30.0  2200.0  20.0    83.0
# ...

# %%
data.isnull().sum()
# Out:
# property_name      0
# seller             0
# facilities         0
# advantages         0
# BHK                0
# property_type      0
# Area_type          0
# avg_sba            0
# area_sqft          0
# Avg_prics          0
# floors             0
# units              0
# tpa                0
# towers             0
# open area        277
# address            0
# dtype: int64

# %%
data.head()
# Out:
#                      property_name  \
# 0  Sumadhuras Gardens By The Brook
# 1  Sumadhuras Gardens By The Brook
# 2                      The Olympus
# 3      Technopolis Solitaire Unity
# 4      Technopolis Solitaire Unity
#
#                                             seller  facilities  advantages  \
# 0              Sumadhura Infracon Pvt. Ltd.Builder        19.0    6.565000
# 1              Sumadhura Infracon Pvt. Ltd.Builder        19.0    6.565000
# 2              Sumadhura Infracon Pvt. Ltd.Builder        27.0    7.209091
# 3  TECHNOPOLIS CONSTRUCTION COMPANY PVT LTDBuilder        21.0    6.225000
# 4  TECHNOPOLIS CONSTRUCTION COMPANY PVT LTDBuilder        21.0    6.225000
#
#    BHK property_type            Area_type  avg_sba                area_sqft  \
# 0  2.0     Apartment  Super Built-up Area   1362.5  (119.38 - 133.78 sq.m.)
# 1  3.0     Apartment  Super Built-up Area   1652.5  (150.97 - 156.08 sq.m.)
# ...

# %%
data.drop(columns=['property_name','seller','property_type','Area_type','area_sqft','open area'],inplace=True)

# %%
data.to_csv('/content/sample_data/Cleaned_data.csv',index=False)
